# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("indian_wines_mart_10_years_city_expanded.csv")
df
# Out:
#        Year  Month  Store_ID        State    City  Wine_Mart_Count_in_City  \
# 0      2015      1         1  Maharashtra  Mumbai                        4
# 1      2015      1         2  Maharashtra  Mumbai                        4
# 2      2015      1         3  Maharashtra  Mumbai                        4
# 3      2015      1         4  Maharashtra  Mumbai                        4
# 4      2015      1         5  Maharashtra  Mumbai                        4
# ...     ...    ...       ...          ...     ...                      ...
# 92955  2024     12     92956        Delhi   Saket                        7
# 92956  2024     12     92957        Delhi   Saket                        7
# 92957  2024     12     92958        Delhi   Saket                        7
# 92958  2024     12     92959        Delhi   Saket                        7
# 92959  2024     12     92960        Delhi   Saket                        7
#
# ...

# %%
df.shape
# Out:
# (92960, 14)

# %%
df.columns
# Out:
# Index(['Year', 'Month', 'Store_ID', 'State', 'City', 'Wine_Mart_Count_in_City',
#        'Wine_Brand', 'Wine_Type', 'Alcohol_Percentage', 'Bottle_Size_ml',
#        'MRP_INR', 'Monthly_Sales_Units', 'Monthly_Revenue_INR',
#        'Customer_Rating'],
#       dtype='object')

# %%
df.head()
# Out:
#    Year  Month  Store_ID        State    City  Wine_Mart_Count_in_City  \
# 0  2015      1         1  Maharashtra  Mumbai                        4
# 1  2015      1         2  Maharashtra  Mumbai                        4
# 2  2015      1         3  Maharashtra  Mumbai                        4
# 3  2015      1         4  Maharashtra  Mumbai                        4
# 4  2015      1         5  Maharashtra  Mumbai                        4
#
#      Wine_Brand Wine_Type  Alcohol_Percentage  Bottle_Size_ml  MRP_INR  \
# 0          Sula       Red                10.2             750     1300
# 1  Grover Zampa       Red                13.3             375     1429
# 2      Fratelli       Red                10.7             375     1196
# 3          York     White                14.9             750      874
# 4    Big Banyan       Red                11.4             375     1915
#
#    Monthly_Sales_Units  Monthly_Revenue_INR  Customer_Rating
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92960 entries, 0 to 92959
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Year                     92960 non-null  int64
#  1   Month                    92960 non-null  int64
#  2   Store_ID                 92960 non-null  int64
#  3   State                    92960 non-null  object
#  4   City                     92960 non-null  object
#  5   Wine_Mart_Count_in_City  92960 non-null  int64
#  6   Wine_Brand               92960 non-null  object
#  7   Wine_Type                92960 non-null  object
#  8   Alcohol_Percentage       92960 non-null  float64
#  9   Bottle_Size_ml           92960 non-null  int64
#  10  MRP_INR                  92960 non-null  int64
#  11  Monthly_Sales_Units      92960 non-null  int64
#  12  Monthly_Revenue_INR      92960 non-null  int64
#  13  Customer_Rating          92960 non-null  float64
# ...

# %% [markdown]
# ## Checking missing values

# %%
df.isnull().sum()
# Out:
# Year                       0
# Month                      0
# Store_ID                   0
# State                      0
# City                       0
# Wine_Mart_Count_in_City    0
# Wine_Brand                 0
# Wine_Type                  0
# Alcohol_Percentage         0
# Bottle_Size_ml             0
# MRP_INR                    0
# Monthly_Sales_Units        0
# Monthly_Revenue_INR        0
# Customer_Rating            0
# dtype: int64

# %% [markdown]
# ## checking duplicated values

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#                Year         Month      Store_ID  Wine_Mart_Count_in_City  \
# count  92960.000000  92960.000000  92960.000000             92960.000000
# mean    2019.503464      6.515587  46480.500000                 6.070030
# std        2.885399      3.443460  26835.384849                 1.625967
# min     2015.000000      1.000000      1.000000                 3.000000
# 25%     2017.000000      4.000000  23240.750000                 5.000000
# 50%     2019.000000      7.000000  46480.500000                 6.000000
# 75%     2022.000000     10.000000  69720.250000                 8.000000
# max     2024.000000     12.000000  92960.000000                 8.000000
#
#        Alcohol_Percentage  Bottle_Size_ml       MRP_INR  Monthly_Sales_Units  \
# count        92960.000000    92960.000000  92960.000000         92960.000000
# mean            12.502669      561.527808   1399.784284           483.728367
# std              1.443434      187.498488    461.535591           253.131410
# ...

# %%
df.describe(include="O")
# Out:
#               State      City Wine_Brand Wine_Type
# count         92960     92960      92960     92960
# unique            5        20          7         4
# top     Maharashtra  Warangal       Sula      Rose
# freq          23513      4893      13280     23302

# %%
df["State"].value_counts()
# Out:
# State
# Maharashtra    23513
# Telangana      18585
# Delhi          18529
# Karnataka      18319
# Goa            14014
# Name: count, dtype: int64

# %%
df["City"].value_counts()
# Out:
# City
# Warangal         4893
# Nagpur           4851
# Vasco da Gama    4851
# Nashik           4781
# Dwarka           4767
# Bengaluru        4760
# New Delhi        4732
# Mumbai           4725
# Karimnagar       4648
# Mangaluru        4634
# Panaji           4620
# Aurangabad       4620
# Nizamabad        4599
# Rohini           4564
# Hubballi         4557
# Margao           4543
# Pune             4536
# Saket            4466
# Hyderabad        4445
# Mysuru           4368
# Name: count, dtype: int64

# %%
df["Wine_Type"].value_counts()
# Out:
# Wine_Type
# Rose         23302
# Red          23287
# Sparkling    23257
# White        23114
# Name: count, dtype: int64

# %%
df["Wine_Brand"].value_counts()
# Out:
# Wine_Brand
# Sula            13280
# Grover Zampa    13280
# Fratelli        13280
# York            13280
# Big Banyan      13280
# Charosa         13280
# KRSMA           13280
# Name: count, dtype: int64

# %%
df.groupby("State")["Wine_Mart_Count_in_City"].sum()
# Out:
# State
# Delhi          111615
# Goa             85400
# Karnataka      110131
# Maharashtra    143983
# Telangana      113141
# Name: Wine_Mart_Count_in_City, dtype: int64

# %%
df.groupby("Wine_Brand")["Alcohol_Percentage"].max()
# Out:
# Wine_Brand
# Big Banyan      15.0
# Charosa         15.0
# Fratelli        15.0
# Grover Zampa    15.0
# KRSMA           15.0
# Sula            15.0
# York            15.0
# Name: Alcohol_Percentage, dtype: float64

# %%
df.groupby("City")["Customer_Rating"].mean()
# Out:
# City
# Aurangabad       3.936558
# Bengaluru        3.947395
# Dwarka           3.940277
# Hubballi         3.948299
# Hyderabad        3.946187
# Karimnagar       3.934187
# Mangaluru        3.954942
# Margao           3.953467
# Mumbai           3.961312
# Mysuru           3.944322
# Nagpur           3.947145
# Nashik           3.945095
# New Delhi        3.939708
# Nizamabad        3.943009
# Panaji           3.942554
# Pune             3.964484
# Rohini           3.955609
# Saket            3.957501
# Vasco da Gama    3.957205
# Warangal         3.941079
# Name: Customer_Rating, dtype: float64

# %%
df.groupby(["Wine_Brand","Bottle_Size_ml"])["MRP_INR"].max()
# Out:
# Wine_Brand    Bottle_Size_ml
# Big Banyan    375               2199
#               750               2199
# Charosa       375               2199
#               750               2199
# Fratelli      375               2199
#               750               2199
# Grover Zampa  375               2199
#               750               2199
# KRSMA         375               2199
#               750               2199
# Sula          375               2198
#               750               2199
# York          375               2199
#               750               2199
# Name: MRP_INR, dtype: int64

# %%
df.groupby("State")["MRP_INR"].max()
# Out:
# State
# Delhi          2199
# Goa            2199
# Karnataka      2199
# Maharashtra    2199
# Telangana      2199
# Name: MRP_INR, dtype: int64

# %%
df.groupby(["State","Bottle_Size_ml"])["Monthly_Sales_Units"].agg(["mean","max","min"])
# Out:
#                                   mean   max  min
# State       Bottle_Size_ml
# Delhi       375             485.256385  1123   52
#             750             478.960973  1123   52
# Goa         375             486.997422  1123   52
#             750             481.211634  1123   53
# Karnataka   375             482.328466  1123   52
#             750             484.051624  1123   52
# Maharashtra 375             488.146315  1123   52
#             750             484.875256  1122   52
# Telangana   375             484.844813  1123   52
#             750             479.176116  1123   52

# %%
df.groupby(["State","Bottle_Size_ml"])["Monthly_Revenue_INR"].agg(["mean","max","min"])
# Out:
#                                      mean      max    min
# State       Bottle_Size_ml
# Delhi       375             615021.412652  2097444  33956
#             750             609730.757189  2121964  36025
# Goa         375             619753.174996  2054840  44668
#             750             616814.216328  2061885  40443
# Karnataka   375             614690.754250  2054945  36835
#             750             618077.496664  2053636  39644
# Maharashtra 375             621576.224253  2089791  41154
#             750             617846.903642  2080598  34503
# Telangana   375             617798.767801  2108465  38396
#             750             611968.121834  2095008  40931

# %% [markdown]
# ## Univariate Analysis

# %%
plt.figure(figsize=(6,4),facecolor="palegreen")
sns.countplot(data=df,x="State",color="lightyellow",edgecolor="black",label="Wine_marts_count")
plt.title("Count_of_wine_mart")
plt.xlabel("States")
plt.ylabel("Wine_marts")
plt.legend()
plt.show()

# %%
plt.pie(df["Wine_Type"].value_counts(),labels=df["Wine_Type"].value_counts().index,autopct="%0.2f%%",shadow=True,startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x185bbd9aba0>,
# ...
#  [Text(-0.7794456411266145, 0.7761858621030926, 'Rose'),
#   Text(-0.7733093349670863, -0.7822996053001451, 'Red'),
#   Text(0.78397033238295, -0.7716155246904817, 'Sparkling'),
#   Text(0.7744983357585898, 0.7811224794532383, 'White')],
#  [Text(-0.42515216788724425, 0.42337410660168684, '25.07%'),
#   Text(-0.4218050918002289, -0.42670887561826093, '25.05%'),
#   Text(0.42762018129979085, -0.4208811952857172, '25.02%'),
#   Text(0.4224536376865035, 0.42606680697449356, '24.86%')])

# %%
fg=plt.figure(figsize=(6,4),facecolor="palegreen")
sns.histplot(data=df,x="Monthly_Sales_Units",color="orange",edgecolor="navy",kde=True,label="Distribution")
plt.title("Monthly_Sales_units distribution")
plt.xlabel("Monthly_Sales_Units")
plt.ylabel("distribution")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(6,4),facecolor="palegreen")
sns.countplot(data=df,x="Wine_Mart_Count_in_City",color="lightyellow",edgecolor="black",label="Count_of_Wine_Marts")
plt.title("Count_of_Wine_Marts_in_Cities")
plt.xlabel("Wine_Mart_Count_in_City")
plt.ylabel("Count")
plt.legend()
plt.show()

# %%
fig=plt.figure(figsize=(5,5))
plt.boxplot(df["Monthly_Sales_Units"],
            patch_artist=True,
            boxprops=dict(facecolor="olive",color="grey",linewidth=2),
            medianprops=dict(color="blue",linewidth=1.8,linestyle="--"),
            meanprops=dict(color="purple",linewidth=2),
            meanline=True)
plt.title("Monlthy_Sales_Units")
plt.ylabel("Units")
plt.grid()

plt.show()

# %% [markdown]
# ## Bivariate Analysis

# %%
pd.crosstab(df["State"],df["Wine_Brand"]).plot(kind="bar")
plt.title("Most_sale_Wine_Brand_State")
plt.xlabel("States")
plt.ylabel("counts")
plt.show()

# %%
pd.crosstab(df["Wine_Type"],df["Wine_Brand"]).plot(kind="bar")
plt.title("Most_used_wine_Type_in Brands")
plt.xlabel("Wine_Type")
plt.ylabel("counts")
plt.show()

# %%
pd.crosstab(df["City"],df["Wine_Mart_Count_in_City"]).plot(kind="bar",figsize=(12,4))
plt.title("Wine_Marts_in States")
plt.xlabel("Wine")
plt.ylabel("counts")
plt.show()

# %%
fig=plt.figure(figsize=(6,6),facecolor="lightgreen")
sns.boxplot(data=df,x="State",y="Monthly_Revenue_INR")
plt.title("State_Monlthy_Revenue")
plt.xlabel("States")
plt.ylabel("Monthly_Revenue")
plt.tight_layout()
plt.show()

# %%
fig=plt.figure(figsize=(14,6),facecolor="lightgreen")
sns.boxplot(data=df,x="City",y="Monthly_Sales_Units")
plt.title("Cities_Monthly_Sales")
plt.xlabel("Cities")
plt.ylabel("Sales")
plt.tight_layout()
plt.show()

# %%
fig=plt.figure(figsize=(8,4),facecolor="lightgreen")
sns.boxplot(data=df,x="Wine_Brand",y="Alcohol_Percentage")
plt.title("Brand_With_Alcholol_Percentage")
plt.xlabel("Brand")
plt.ylabel("Alcholol_Percentage")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Numericall to time

# %%
plt.figure(figsize=(12,4))
plt.plot(df["Year"],df["Monthly_Sales_Units"])
plt.title("Last_10_Years_Sales")
plt.xlabel("Year")
plt.ylabel("Sales")
plt.yticks()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(12,4))
plt.plot(df["Year"],df["Monthly_Revenue_INR"])
plt.title("Last_10_Years_Revenue")
plt.xlabel("Year")
plt.ylabel("Revenue")
plt.yticks()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(12,4))
plt.plot(df["Year"],df["MRP_INR"])
plt.title("Last_10_Years_MRPs")
plt.xlabel("Year")
plt.ylabel("MRP")
plt.yticks()
plt.grid()
plt.show()

# %% [markdown]
# ## sCATTER PLOT

# %%
sns.scatterplot(data=df,x="MRP_INR",y="Monthly_Revenue_INR")
# Out:
# <Axes: xlabel='MRP_INR', ylabel='Monthly_Revenue_INR'>

# %%
sns.heatmap(data=df[["Monthly_Revenue_INR","MRP_INR","Monthly_Sales_Units"]].corr(),annot=True,cmap="Greens")
# Out:
# <Axes: >

# %%
sns.pairplot(data=df[["Alcohol_Percentage","MRP_INR"]])

# %%
df.groupby("Year")["Monthly_Sales_Units"].mean().plot(kind="line")
plt.title("Yearly_Average_Sales")
plt.xlabel("Year")
plt.ylabel("Sales")
plt.show()

# %%
df.groupby("Year")["Monthly_Revenue_INR"].mean().plot(kind="line")
plt.title("Yearly_Average_Revenue")
plt.xlabel("Year")
plt.ylabel("Revenue")
plt.show()

# %%
df.groupby("Year")["MRP_INR"].mean().plot(kind="line")
plt.title("Yearly_Average_MRP")
plt.xlabel("Year")
plt.ylabel("MRP")
plt.show()

# %%
df.groupby("Year")["Customer_Rating"].mean().plot(kind="line")
plt.title("Yearly_Average_Customer_Ratings")
plt.xlabel("Year")
plt.ylabel("Ratings")
plt.show()

# %%
sns.pairplot(data=df[["Year","Month","Monthly_Sales_Units","Monthly_Revenue_INR"]])
